# %%
import os
import shutil
import numpy as np # linear algebra
import tensorflow as tf
from keras.utils import image_dataset_from_directory, load_img
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, regularizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
data = image_dataset_from_directory(
    'flowers',
    image_size=(128, 128))
# Out:
# Found 1785 files belonging to 2 classes.

# %%
images, labels = [], []
for image, label in data:
    images.append(image.numpy())
    labels.append(label.numpy())
images, labels =  np.concatenate(images), np.concatenate(labels)
images /= 255.0

# %%
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten()

for i in range(25):
    axes[i].imshow(images[i])
    axes[i].axis('off')  # Hide axis
    axes[i].set_title(f"Label: {labels[i]}")

plt.tight_layout()

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, shuffle=True, random_state=11, stratify=labels)

# %%
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 15
#       7 train_datagen = ImageDataGenerator(
#       8     rotation_range=90,
#       9     horizontal_flip=True,
#      10     fill_mode='nearest',
#      11 )
#      13 train_generator = train_datagen.flow(X_train, y_train, batch_size=16)
# ---> 15 history = model.fit(
#      16     train_generator,
#      17     validation_data=(X_test, y_test),
#      18     epochs=50,
#      19     callbacks=[early_stopping]
#      20 )
#
# File c:\Users\patri\Python\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\patri\Python\Lib\site-packages\keras\src\models\sequential.py:160, in Sequential.build(self, input_shape)
#     158     return
#     159 if not self._layers:
# --> 160     raise ValueError(
#     161         f"Sequential model {self.name} cannot be built because it has "
#     162         "no layers. Call `model.add(layer)`."
#     163     )
#     164 if isinstance(self._layers[0], InputLayer):
#     165     if self._layers[0].batch_shape != input_shape:
#
# ValueError: Sequential model sequential cannot be built because it has no layers. Call `model.add(layer)`.
